# %%
import tensorflow as tf
import numpy as np

# %%
x= np.array([1,2,3,4],dtype=float)
y= np.array([2,4,6,8],dtype=float)

model=tf.keras.Sequential([tf.keras.Input(shape=(1,)),
                           tf.keras.layers.Dense(1)])
model.compile(optimizer='sgd',loss='mean_squared_error')
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - loss: 3.9070
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.7134
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.8852
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3105
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.9117
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6350
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4430
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3097
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2172
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1530

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
x= np.array([1,2,3,4],dtype=float)
y= np.array([2,4,6,8],dtype=float)

model=Sequential([Dense(1,input_shape=(1,))
])
model.compile(optimizer='sgd',loss='mse')
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 34.1987
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 23.7510
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 16.5014
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 11.4710
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 7.9803
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.5581
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.8773
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.7109
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.9014
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.3396

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#define a single linear model
model = nn.Linear(1,1)

#loss and optimizer
criteria = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

#dummy data
x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

#training loop
for epoch in range(10):
    optimizer.zero_grad()
    outputs=model(x)
    loss=criteria(outputs,y)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 60.69284439086914
# Epoch 2, Loss: 42.113525390625
# Epoch 3, Loss: 29.221725463867188
# Epoch 4, Loss: 20.276378631591797
# Epoch 5, Loss: 14.069393157958984
# Epoch 6, Loss: 9.76249885559082
# Epoch 7, Loss: 6.774031639099121
# Epoch 8, Loss: 4.700399398803711
# Epoch 9, Loss: 3.261549949645996
# Epoch 10, Loss: 2.263162612915039
